# %% [markdown]
# # Install Libraries

# %% [markdown]
# # Import Libraries

# %%
# Installs
# !pip install -q torch==2.4.1 torchvision==0.19.1 transformers==4.44.2 pillow==10.4.
# !pip install pdfplumber
# !pip install reportlab
# !pip install langgraph langchain langchain-core

# Imports
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.lib.styles import getSampleStyleSheet
from langgraph.graph import StateGraph, END
from typing import TypedDict

# Run Cell
app = graph.compile()
result = app.invoke({
    "pdf_path":
    "Rental Agreement Template.pdf"
})
print(
    result["report"]
)
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x7fef57f28cc0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1147, in __del__
#     def __del__(self):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7036/795245974.py in <cell line: 0>()
#       7
#       8 app = graph.compile()
# ----> 9 result = app.invoke({
#      10     "pdf_path":
#      11     "Rental Agreement Template.pdf"
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3926         else:
#    3927             # v1: collect interrupts from updates stream
# -> 3928             for chunk in self.stream(
#    3929                 input,
# ...

# %% [markdown]
# # PDF Extractor

# %% [markdown]
# # Text Cleaner

# %% [markdown]
# # Chunking

# %% [markdown]
# # Load Models

# %% [markdown]
# # Summarizer Agent

# %% [markdown]
# # Classificatin Agent

# %% [markdown]
# # Analyzer Agent

# %% [markdown]
# # Drafting agent

# %% [markdown]
# # Report generator

# %% [markdown]
# # Save report as txt

# %% [markdown]
# # Orchestration (main pipeline)

# %% [markdown]
# # States

# %% [markdown]
# # Agent 1 Extracter

# %% [markdown]
# # Agent 2 Cleaner

# %% [markdown]
# # Agent 3 Summarizer

# %% [markdown]
# # Agent 4 Classifier

# %% [markdown]
# # Agent 5 Risk Analyzer

# %% [markdown]
# # Agent 6 Report Generator

# %% [markdown]
# # Build Graph

# %% [markdown]
# # Connect Agents

# %% [markdown]
# # Compile

# %% [markdown]
# # Run

# %%
app = graph.compile()

result = app.invoke({

    "pdf_path":
    "Rental Agreement Template.pdf"

})

print(
    result["report"]
)
